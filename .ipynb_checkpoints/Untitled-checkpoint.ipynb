# %%
# !python final_pred.py
# Out:
# Starting Application...
# Loaded model from disk
#   0
#
# ...
# 1/1 [==============================] - 0s 309ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
#   1
#
# ...
# 1/1 [==============================] - 0s 64ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
#   2
#
# ...
# 1/1 [==============================] - 0s 54ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
#   3
#
# ...
# 1/1 [==============================] - 0s 63ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# 666663
# True
#   4
#
# ...
# 1/1 [==============================] - 0s 67ms/step
# 2222  ch1=+++++++++++++++++ 7 , 2
# True
#   5
#
# ...
# 1/1 [==============================] - 0s 55ms/step
# 2222  ch1=+++++++++++++++++ 5 , 4
# 111114
# True
#   6
#
# ...
# 1/1 [==============================] - 0s 56ms/step
# 2222  ch1=+++++++++++++++++ 7 , 6
# 111114
# 111114lll;;p
# True
#   7
#
# ...
# 1/1 [==============================] - 0s 56ms/step
# 2222  ch1=+++++++++++++++++ 2 , 2
# True
#   8
#
# ...
# 1/1 [==============================] - 0s 56ms/step
# ...

# %%
# !pip install PyEnchant

# %%
+
